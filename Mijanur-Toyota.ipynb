# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
df=pd.read_csv('Toyota (1) (1).csv')
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
import pandas as pd
df = pd.read_csv("Toyota (1) (1).csv", index_col=0, na_values=["?", "??", "???","????","????"])
df
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
df.shape
# Out:
# (1436, 10)

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      4
# float64    4
# object     2
# dtype: int64

# %%
df["KM"].unique()
# Out:
# array([46986., 72937., 41711., ..., 30964., 20544., 17016.])

# %%
df.replace("three",3,inplace=True)
df.replace("four",4,inplace=True)
df.replace("five",5,inplace=True)
df
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000     3
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000     3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000     3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000     3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000     3
# ...     ...   ...      ...      ...    ...       ...        ...   ...   ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300     3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300     3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300     3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300     3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600     5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
total_missing = df.isnull().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df['Age'].fillna(df["Age"].mean(),inplace=True)

# %%
df
# Out:
#       Price        Age       KM FuelType     HP  MetColor  Automatic    CC  \
# 0     13500  23.000000  46986.0   Diesel   90.0       1.0          0  2000
# 1     13750  23.000000  72937.0   Diesel   90.0       1.0          0  2000
# 2     13950  24.000000  41711.0   Diesel   90.0       NaN          0  2000
# 3     14950  26.000000  48000.0   Diesel   90.0       0.0          0  2000
# 4     13750  30.000000  38500.0   Diesel   90.0       0.0          0  2000
# ...     ...        ...      ...      ...    ...       ...        ...   ...
# 1431   7500  55.672156  20544.0   Petrol   86.0       1.0          0  1300
# 1432  10845  72.000000      NaN   Petrol   86.0       0.0          0  1300
# 1433   8500  55.672156  17016.0   Petrol   86.0       0.0          0  1300
# 1434   7250  70.000000      NaN      NaN   86.0       1.0          0  1300
# 1435   6950  76.000000      1.0   Petrol  110.0       0.0          0  1600
#
#      Doors  Weight
# 0        3    1165
# 1        3    1165
# ...

# %%
df["KM"].fillna(df["KM"].mean(),inplace=True)
df
# Out:
#       Price        Age            KM FuelType     HP  MetColor  Automatic  \
# 0     13500  23.000000  46986.000000   Diesel   90.0       1.0          0
# 1     13750  23.000000  72937.000000   Diesel   90.0       1.0          0
# 2     13950  24.000000  41711.000000   Diesel   90.0       NaN          0
# 3     14950  26.000000  48000.000000   Diesel   90.0       0.0          0
# 4     13750  30.000000  38500.000000   Diesel   90.0       0.0          0
# ...     ...        ...           ...      ...    ...       ...        ...
# 1431   7500  55.672156  20544.000000   Petrol   86.0       1.0          0
# 1432  10845  72.000000  68647.239972   Petrol   86.0       0.0          0
# 1433   8500  55.672156  17016.000000   Petrol   86.0       0.0          0
# 1434   7250  70.000000  68647.239972      NaN   86.0       1.0          0
# 1435   6950  76.000000      1.000000   Petrol  110.0       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# 1     2000     3    1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB

# %%
total_missing = df.isnull().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: Price          0
# Age            0
# KM             0
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df["FuelType"].mode()
# Out:
# 0    Petrol
# Name: FuelType, dtype: object

# %%
df["FuelType"].unique
# Out:
# <bound method Series.unique of 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434       NaN
# 1435    Petrol
# Name: FuelType, Length: 1436, dtype: object>

# %%
df["FuelType"].value_counts()
# Out:
# Petrol    1177
# Diesel     144
# CNG         15
# Name: FuelType, dtype: int64

# %%
df["FuelType"].fillna(df["FuelType"].value_counts().index[0],inplace=True)
df
# Out:
#       Price        Age            KM FuelType     HP  MetColor  Automatic  \
# 0     13500  23.000000  46986.000000   Diesel   90.0       1.0          0
# 1     13750  23.000000  72937.000000   Diesel   90.0       1.0          0
# 2     13950  24.000000  41711.000000   Diesel   90.0       NaN          0
# 3     14950  26.000000  48000.000000   Diesel   90.0       0.0          0
# 4     13750  30.000000  38500.000000   Diesel   90.0       0.0          0
# ...     ...        ...           ...      ...    ...       ...        ...
# 1431   7500  55.672156  20544.000000   Petrol   86.0       1.0          0
# 1432  10845  72.000000  68647.239972   Petrol   86.0       0.0          0
# 1433   8500  55.672156  17016.000000   Petrol   86.0       0.0          0
# 1434   7250  70.000000  68647.239972   Petrol   86.0       1.0          0
# 1435   6950  76.000000      1.000000   Petrol  110.0       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# 1     2000     3    1165
# ...

# %%
total_missing = df.isnull().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: Price          0
# Age            0
# KM             0
# FuelType       0
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
df.MetColor
# Out:
# 0       1.0
# 1       1.0
# 2       NaN
# 3       0.0
# 4       0.0
#        ...
# 1431    1.0
# 1432    0.0
# 1433    0.0
# 1434    1.0
# 1435    0.0
# Name: MetColor, Length: 1436, dtype: float64

# %%
df["MetColor"].value_counts()
# Out:
# 1.0    868
# 0.0    418
# Name: MetColor, dtype: int64

# %%
df["MetColor"].fillna(df["MetColor"].value_counts().index[0],inplace=True)
df
# Out:
#       Price        Age            KM FuelType     HP  MetColor  Automatic  \
# 0     13500  23.000000  46986.000000   Diesel   90.0       1.0          0
# 1     13750  23.000000  72937.000000   Diesel   90.0       1.0          0
# 2     13950  24.000000  41711.000000   Diesel   90.0       1.0          0
# 3     14950  26.000000  48000.000000   Diesel   90.0       0.0          0
# 4     13750  30.000000  38500.000000   Diesel   90.0       0.0          0
# ...     ...        ...           ...      ...    ...       ...        ...
# 1431   7500  55.672156  20544.000000   Petrol   86.0       1.0          0
# 1432  10845  72.000000  68647.239972   Petrol   86.0       0.0          0
# 1433   8500  55.672156  17016.000000   Petrol   86.0       0.0          0
# 1434   7250  70.000000  68647.239972   Petrol   86.0       1.0          0
# 1435   6950  76.000000      1.000000   Petrol  110.0       0.0          0
#
#         CC Doors  Weight
# 0     2000     3    1165
# 1     2000     3    1165
# ...

# %%
total_missing = df.isnull().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: Price        0
# Age          0
# KM           0
# FuelType     0
# HP           6
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='Age', y='Price',color="violet", data=df)
plt.title('Scatter Plot of Age vs Price')
plt.xlabel('Age')
plt.ylabel('Price')
plt.show()

# %%
plt.hist(df["KM"], bins=10, color='violet', edgecolor='Red')
plt.title('Histogram of KM')
plt.xlabel('KM')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(df["Age"], shade=True, color='Violet')
plt.title('Density Plot of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
sns.boxplot(df["Price"],color="Violet")
plt.title('boxplot of Price')
plt.xlabel("Frequency")
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
sns.countplot(df["FuelType"],hue="Automatic",data=df)
plt.title('Countplot of FuelType')
plt.xlabel("FuelType")
plt.ylabel('Automatic')
plt.grid(True)
plt.show()

# %%
df["FuelType"].value_counts()
# Out:
# Petrol    1277
# Diesel     144
# CNG         15
# Name: FuelType, dtype: int64
